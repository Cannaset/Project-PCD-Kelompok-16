# %% [markdown]
# ## Percobaan 02: Preprocessing Citra
#
# Notebook ini berisi tahap kedua preprocessing citra. Proses yang dilakukan meliputi pembacaan dataset, penyeragaman ukuran citra, konversi grayscale dan, filtering.

# %% [markdown]
# ## Import Library
#
# Bagian ini mengimpor library yang dibutuhkan untuk proses pengolahan citra, ekstraksi fitur, pelatihan model, dan evaluasi klasifikasi. Library `os` dan `pathlib` digunakan untuk mengakses serta mengelola folder dataset. Library `cv2`, `numpy`, dan `matplotlib` digunakan untuk membaca, mengolah, serta memvisualisasikan citra. Library `pandas` dan `seaborn` digunakan untuk pengelolaan data dan visualisasi hasil analisis. Library `scipy.stats` digunakan untuk menghitung nilai entropi, sedangkan `skimage.feature` digunakan untuk ekstraksi fitur tekstur menggunakan metode GLCM. Selain itu, library `scikit-learn` digunakan untuk membagi data latih dan data uji, membangun model klasifikasi menggunakan Random Forest, SVM, dan KNN, serta mengevaluasi performa model berdasarkan akurasi, precision, recall, F1-score, dan confusion matrix.

# %%
# Import library yang dibutuhkan
import os
from pathlib import Path

import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from scipy.stats import entropy
from skimage.feature import graycomatrix, graycoprops

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay,
)

# %% [markdown]
# ### Pembacaan dan Pengelompokan Dataset
#
# Bagian ini digunakan untuk membaca seluruh citra yang terdapat pada folder dataset dan mengelompokkannya berdasarkan kelas masing-masing. Variabel PROJECT_ROOT digunakan untuk menentukan direktori kerja saat ini, sedangkan DATASET_DIR digunakan untuk mengakses folder dataset yang berisi citra. Variabel VALID_EXTENSIONS digunakan untuk membatasi jenis file yang dapat diproses, yaitu gambar dengan format JPG, JPEG, PNG, dan BMP.
#
# Selanjutnya, program melakukan iterasi pada setiap folder kelas yang terdapat di dalam dataset. Setiap citra yang ditemukan akan dibaca menggunakan library OpenCV (cv.imread()). Jika citra berhasil dibaca, data citra disimpan ke dalam variabel data, nama kelas disimpan pada variabel labels, dan nama file disimpan pada variabel file_name. Setelah seluruh citra diproses, data dikonversi menjadi array NumPy untuk memudahkan proses pengolahan selanjutnya. Program juga menampilkan jumlah gambar pada setiap kelas serta total keseluruhan data yang berhasil dimuat sebagai informasi distribusi dataset yang digunakan dalam penelitian.

# %%
PROJECT_ROOT = Path.cwd()
DATASET_DIR = PROJECT_ROOT / "dataset"

VALID_EXTENSIONS = {".jpg", ".jpeg", ".png", ".bmp"}

print("Folder dataset:", DATASET_DIR.resolve())
# Out:
# Folder dataset: D:\ASUS\Documents\SEMS 4\Praktikum PCD\Projek\Project-PCD-Kelompok-16\dataset

# %%
data = []
labels = []
file_name = []

for class_folder in sorted(DATASET_DIR.iterdir()):
    if not class_folder.is_dir():
        continue

    label = class_folder.name
    image_files = [
        file for file in sorted(class_folder.iterdir())
        if file.suffix.lower() in VALID_EXTENSIONS
    ]

    print(f"{label}: {len(image_files)} gambar")

    for image_path in image_files:
        image = cv.imread(str(image_path))

        if image is None:
            print("Gagal membaca gambar:", image_path)
            continue

        data.append(image.astype(np.uint8))
        labels.append(label)
        file_name.append(image_path.name)

data = np.array(data, dtype=object)
labels = np.array(labels)
file_name = np.array(file_name)

print("\nTotal data:", len(data))
print(pd.Series(labels).value_counts())
# Out:
# catterpillar: 70 gambar
# snail: 70 gambar
#
# Total data: 140
# catterpillar    70
# snail           70
# Name: count, dtype: int64

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ### Define Augmentation Function
#
#
# Bagian ini digunakan untuk mengatur proses augmentasi data citra sebelum dilakukan ekstraksi fitur dan pelatihan model. Fungsi `augment_image()` disediakan sebagai tempat untuk menambahkan berbagai teknik augmentasi citra, seperti rotasi, flipping, scaling, atau transformasi lainnya. Pada kode ini, fungsi tersebut masih mengembalikan daftar kosong sehingga tidak ada citra tambahan yang dihasilkan.
#
# Variabel `USE_AUGMENTATION` digunakan sebagai penanda apakah proses augmentasi akan dijalankan atau tidak. Ketika bernilai `False`, program hanya menggunakan data citra asli yang telah dibaca dari dataset. Sebaliknya, jika bernilai `True`, program akan menghasilkan citra baru dari setiap citra asli menggunakan fungsi augmentasi, kemudian menambahkannya ke dalam dataset beserta label dan nama file yang sesuai. Setelah proses selesai, seluruh data, label, dan nama file dikonversi kembali ke dalam bentuk array NumPy. Program juga menampilkan jumlah data sebelum dan sesudah augmentasi untuk mengetahui perubahan ukuran dataset yang digunakan pada proses klasifikasi.

# %%
def augment_image(image):
    return []

# %%
USE_AUGMENTATION = False

data_used = list(data)
labels_used = list(labels)
file_name_used = list(file_name)

if USE_AUGMENTATION:
    for image, label, filename in zip(data, labels, file_name):
        for index, augmented_image in enumerate(augment_image(image), start=1):
            data_used.append(augmented_image.astype(np.uint8))
            labels_used.append(label)
            name, ext = os.path.splitext(filename)
            file_name_used.append(f"{name}_aug{index}{ext}")

data_used = np.array(data_used, dtype=object)
labels_used = np.array(labels_used)
file_name_used = np.array(file_name_used)

print("Data sebelum augmentasi:", len(data))
print("Data yang digunakan:", len(data_used))
# Out:
# Data sebelum augmentasi: 140
# Data yang digunakan: 140

# %% [markdown]
# ## Data Preparation
#
#
#
# ### Define Preprocessing Function
#
# Bagian ini digunakan untuk melakukan preprocessing citra sebelum proses ekstraksi fitur dilakukan. Tahap pertama adalah mengubah ukuran citra menjadi ukuran yang seragam, yaitu 384 × 256 piksel menggunakan fungsi resize_grayscale(). Setelah proses resize, citra dikonversi ke format grayscale apabila masih berupa citra berwarna. Konversi ini bertujuan untuk mengurangi kompleksitas data dan mempermudah proses pengolahan citra selanjutnya.
#
# Selanjutnya, fungsi filter() digunakan untuk melakukan perbaikan kualitas citra melalui proses filtering. Fungsi ini menyediakan beberapa jenis filter, yaitu mean filter untuk menghaluskan citra berdasarkan rata-rata nilai piksel di sekitar area kernel, median filter untuk mengurangi noise dengan mengganti nilai piksel menggunakan nilai tengah pada area kernel, dan modus filter untuk mengganti nilai piksel berdasarkan nilai yang paling sering muncul pada area kernel. Pada penelitian ini digunakan median filter dengan ukuran kernel 3×3 karena efektif dalam mengurangi noise tanpa menghilangkan detail penting pada citra.
#
# Fungsi prepo2() merupakan fungsi utama preprocessing yang menggabungkan proses konversi grayscale dan median filtering. Hasil dari fungsi ini adalah citra grayscale yang telah diperbaiki kualitasnya dan siap digunakan pada tahap ekstraksi fitur tekstur.

# %%
TARGET_SIZE = (384, 256)


def resize_grayscale(image, target_size=TARGET_SIZE):
    resized = cv.resize(image, target_size)

    if len(resized.shape) == 3:
        gray = cv.cvtColor(resized, cv.COLOR_BGR2GRAY)
    else:
        gray = resized

    return gray.astype(np.uint8)


def filter(img, size, mode):
    # dimensi gambar
    height, width = img.shape

    # ukuran padding
    pad = size // 2

    # tambah padding di sisi gambar
    padded = np.pad(img, pad, mode="edge")

    # canvas hasil
    canvas = np.zeros_like(img, dtype=np.uint8)

    match mode:

        # FILTER RATA-RATA / MEAN FILTER
        case "mean":
            area = size * size

            for i in range(height):
                for j in range(width):

                    # area kernel
                    region = padded[i:i+size, j:j+size]

                    # hitung mean
                    canvas[i, j] = np.sum(region) / area

        # FILTER MEDIAN
        case "median":
            for i in range(height):
                for j in range(width):

                    # area kernel
                    region = padded[i:i+size, j:j+size]

                    # hitung median
                    canvas[i, j] = np.median(region)

        # FILTER MODUS / MODE FILTER
        case "modus":
            for i in range(height):
                for j in range(width):

                    # area kernel
                    region = padded[i:i+size, j:j+size]

                    # flatten array
                    values = region.ravel()

                    # hitung frekuensi
                    count = {}

                    for val in values:
                        if val in count:
                            count[val] += 1
                        else:
                            count[val] = 1

                    # cari nilai terbanyak
                    max_count = 0
                    mode_val = 0

                    for val, freq in count.items():
                        if freq > max_count:
                            max_count = freq
                            mode_val = val

                    # simpan hasil
                    canvas[i, j] = mode_val

    # kembalikan gambar
    return canvas


def prepo2(image):
    gray = resize_grayscale(image)
    median = filter(gray, 3, "median")
    return median

# %% [markdown]
# ### Preprocessing
#
#
# Bagian ini digunakan untuk menerapkan tahapan preprocessing pada seluruh citra yang terdapat dalam dataset. Setiap citra pada variabel data_used diproses menggunakan fungsi prepo2(), yang mencakup proses resize, konversi grayscale, dan median filtering. Hasil preprocessing dari setiap citra kemudian disimpan ke dalam variabel dataPreprocessed.
#
# Setelah seluruh citra selesai diproses, data hasil preprocessing dikonversi menjadi array NumPy menggunakan fungsi np.stack() sehingga seluruh citra memiliki dimensi yang seragam dan dapat digunakan pada tahap ekstraksi fitur. Selanjutnya, tipe data citra diubah menjadi uint8 untuk memastikan nilai piksel berada pada rentang yang sesuai. Program juga menampilkan informasi jumlah data hasil preprocessing, ukuran target citra yang digunakan, bentuk (shape) salah satu citra, serta tipe data citra sebagai verifikasi bahwa proses preprocessing telah berhasil dilakukan dengan benar.

# %%
dataPreprocessed = []

for image in data_used:
    dataPreprocessed.append(prepo2(image))

dataPreprocessed = np.stack(dataPreprocessed).astype(np.uint8)

print("Jumlah data setelah preprocessing:", len(dataPreprocessed))
print("Ukuran target (width, height):", TARGET_SIZE)
print("Shape contoh gambar:", dataPreprocessed[0].shape)
print("Tipe data gambar:", dataPreprocessed.dtype)
# Out:
# Jumlah data setelah preprocessing: 140
# Ukuran target (width, height): (384, 256)
# Shape contoh gambar: (256, 384)
# Tipe data gambar: uint8

# %% [markdown]
# ### Menampilkan Gambar Dataset
#
#
# Bagian ini digunakan untuk menampilkan beberapa contoh citra hasil preprocessing sebagai tahap verifikasi visual. Sebanyak lima citra dari kelas caterpillar dan lima citra dari kelas snail dipilih berdasarkan indeks tertentu yang telah ditentukan sebelumnya. Pemilihan sampel dari masing-masing kelas bertujuan untuk melihat hasil preprocessing pada kedua kategori data yang digunakan dalam penelitian.
#
# Citra-citra tersebut kemudian ditampilkan menggunakan library Matplotlib dalam susunan 2 baris dan 5 kolom. Setiap citra ditampilkan dalam format grayscale sesuai dengan hasil preprocessing, serta dilengkapi informasi nama kelas dan nama file citra. Visualisasi ini digunakan untuk memastikan bahwa proses resize, konversi grayscale, dan filtering telah berjalan dengan baik sehingga citra yang dihasilkan siap digunakan pada tahap ekstraksi fitur dan klasifikasi.

# %%
# 5 gambar caterpillar
idx_caterpillar = [0, 1, 2, 3, 4]

# 5 gambar snail
idx_snail = [77, 78, 79, 80, 81]

indeks_tampil = idx_caterpillar + idx_snail

fig, axes = plt.subplots(2, 5, figsize=(15, 6))
axes = axes.ravel()

for ax, idx in zip(axes, indeks_tampil):
    ax.imshow(dataPreprocessed[idx], cmap="gray")
    ax.set_title(
        f"{labels_used[idx]}\n{file_name_used[idx]}",
        fontsize=9
    )
    ax.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feature Extraction
#
#
# Bagian ini digunakan untuk mengekstraksi fitur tekstur dari citra hasil preprocessing menggunakan metode Gray Level Co-occurrence Matrix (GLCM). Fungsi glcm() digunakan untuk membentuk matriks ko-okurensi berdasarkan hubungan antar piksel dengan jarak 1 piksel pada empat orientasi sudut, yaitu 0°, 45°, 90°, dan 135°. Matriks yang dihasilkan kemudian dinormalisasi agar dapat digunakan untuk perhitungan fitur tekstur.
#
# Selanjutnya, beberapa fungsi dibuat untuk menghitung karakteristik tekstur dari matriks GLCM, yaitu Contrast, Homogeneity, Dissimilarity, Entropy, ASM (Angular Second Moment), Energy, dan Correlation. Fungsi safe_value() digunakan untuk memastikan bahwa nilai fitur yang dihasilkan tidak mengandung nilai tidak valid seperti NaN atau Infinity, sehingga proses pengolahan data dapat berjalan dengan aman.
#
# Fungsi extract_glcm_features() bertugas melakukan ekstraksi seluruh fitur GLCM pada setiap sudut orientasi yang digunakan. Dari setiap sudut diperoleh tujuh fitur tekstur, sehingga total fitur yang dihasilkan adalah 28 fitur untuk setiap citra. Fitur-fitur tersebut merepresentasikan karakteristik pola tekstur yang terdapat pada citra dan akan digunakan sebagai masukan pada proses klasifikasi.
#
# Setelah proses ekstraksi selesai, seluruh fitur yang diperoleh dari setiap citra disimpan ke dalam bentuk tabel menggunakan DataFrame dari library Pandas. Selain fitur tekstur, tabel juga menyimpan informasi nama file dan label kelas masing-masing citra. Dataset hasil ekstraksi fitur ini kemudian menjadi data masukan utama untuk tahap pelatihan dan pengujian model klasifikasi.

# %%
def glcm(image, derajat):
    if derajat == 0:
        angles = [0]
    elif derajat == 45:
        angles = [np.pi / 4]
    elif derajat == 90:
        angles = [np.pi / 2]
    elif derajat == 135:
        angles = [3 * np.pi / 4]
    else:
        raise ValueError("Derajat harus salah satu dari: 0, 45, 90, 135.")

    return graycomatrix(
        image,
        distances=[1],
        angles=angles,
        levels=256,
        symmetric=True,
        normed=True,
    )


def safe_value(value):
    value = float(value)
    if np.isnan(value) or np.isinf(value):
        return 0.0
    return value

# %%
def correlation(matriks):
    return safe_value(graycoprops(matriks, "correlation")[0, 0])


def dissimilarity(matriks):
    return safe_value(graycoprops(matriks, "dissimilarity")[0, 0])


def homogenity(matriks):
    return safe_value(graycoprops(matriks, "homogeneity")[0, 0])


def contrast(matriks):
    return safe_value(graycoprops(matriks, "contrast")[0, 0])


def ASM(matriks):
    return safe_value(graycoprops(matriks, "ASM")[0, 0])


def energy(matriks):
    return safe_value(graycoprops(matriks, "energy")[0, 0])


def entropyGlcm(matriks):
    return safe_value(entropy(matriks.ravel()))

# %%
def extract_glcm_features(image):
    if image.ndim == 3:
        image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

    image = image.astype(np.uint8)
    features = {}

    for derajat in [0, 45, 90, 135]:
        matriks = glcm(image, derajat)
        features[f"Contrast{derajat}"] = contrast(matriks)
        features[f"Homogeneity{derajat}"] = homogenity(matriks)
        features[f"Dissimilarity{derajat}"] = dissimilarity(matriks)
        features[f"Entropy{derajat}"] = entropyGlcm(matriks)
        features[f"ASM{derajat}"] = ASM(matriks)
        features[f"Energy{derajat}"] = energy(matriks)
        features[f"Correlation{derajat}"] = correlation(matriks)

    return features

# %%
rows = []

for image, label, filename in zip(dataPreprocessed, labels_used, file_name_used):
    row = {
        "Filename": filename,
        "Label": label,
    }
    row.update(extract_glcm_features(image))
    rows.append(row)

hasilEkstrak = pd.DataFrame(rows)
hasilEkstrak.head()
# Out:
#              Filename         Label   Contrast0  Homogeneity0  Dissimilarity0  \
# 0  Caterpillar-01.jpg  catterpillar  127.244686      0.532143        4.432125
# 1  Caterpillar-02.jpg  catterpillar  206.083928      0.468005        5.392083
# 2  Caterpillar-03.jpg  catterpillar  157.081511      0.593194        4.111252
# 3  Caterpillar-04.jpg  catterpillar   86.069945      0.367824        4.302179
# 4  Caterpillar-05.jpg  catterpillar  214.222656      0.610970        5.450810
#
#    Entropy0      ASM0   Energy0  Correlation0  Contrast45  ...     ASM90  \
# 0  7.640050  0.002426  0.049257      0.977351  229.349235  ...  0.001908
# 1  7.854042  0.001296  0.036002      0.971431  399.416997  ...  0.000981
# 2  7.216234  0.003104  0.055713      0.956494  157.284554  ...  0.002933
# 3  7.938188  0.000760  0.027566      0.973859  153.799242  ...  0.000692
# 4  6.432569  0.072459  0.269182      0.977200  377.047059  ...  0.070187
#
# ...

# %% [markdown]
# ### Hasil Ekstraksi Fitur
#
#
# Bagian ini digunakan untuk menampilkan hasil ekstraksi fitur tekstur yang telah diperoleh dari seluruh citra pada dataset. Perintah len(hasilEkstrak) digunakan untuk menghitung jumlah data yang berhasil diekstraksi, sedangkan variabel hasilEkstrak ditampilkan untuk melihat keseluruhan isi tabel fitur yang telah terbentuk.
#
# Tabel hasil ekstraksi berisi informasi nama file (Filename), label kelas (Label), serta seluruh fitur tekstur GLCM yang diperoleh dari empat orientasi sudut pengamatan, yaitu 0°, 45°, 90°, dan 135°. Hasil ini digunakan untuk memastikan bahwa proses ekstraksi fitur telah berjalan dengan baik dan seluruh data siap digunakan pada tahap pembagian data, pelatihan model, serta evaluasi klasifikasi.

# %%
print("Jumlah data hasil ekstraksi:", len(hasilEkstrak))
hasilEkstrak
# Out:
# Jumlah data hasil ekstraksi: 140
#                Filename         Label   Contrast0  Homogeneity0  \
# 0    Caterpillar-01.jpg  catterpillar  127.244686      0.532143
# 1    Caterpillar-02.jpg  catterpillar  206.083928      0.468005
# 2    Caterpillar-03.jpg  catterpillar  157.081511      0.593194
# 3    Caterpillar-04.jpg  catterpillar   86.069945      0.367824
# 4    Caterpillar-05.jpg  catterpillar  214.222656      0.610970
# ..                  ...           ...         ...           ...
# 135      snail (95).jpg         snail   74.263840      0.311642
# 136      snail (96).jpg         snail   43.377366      0.489466
# 137      snail (97).jpg         snail   47.822036      0.501397
# 138      snail (98).jpg         snail   17.108457      0.419646
# 139      snail (99).jpg         snail    7.224808      0.558991
#
#      Dissimilarity0  Entropy0      ASM0   Energy0  Correlation0  Contrast45  \
# 0          4.432125  7.640050  0.002426  0.049257      0.977351  229.349235
# ...

# %% [markdown]
# ### Features Selection
#
# ### **Seleksi Fitur Berdasarkan Korelasi**
#
# Bagian ini digunakan untuk melakukan seleksi fitur guna mengurangi redundansi data dan meningkatkan efisiensi proses klasifikasi. Tahap awal dilakukan dengan mengambil seluruh fitur numerik hasil ekstraksi GLCM, kemudian menghitung nilai korelasi antar fitur menggunakan metode korelasi Pearson. Nilai korelasi yang digunakan adalah nilai absolut sehingga hubungan positif maupun negatif dapat dipertimbangkan dengan tingkat kekuatan yang sama.
#
# Selanjutnya, diterapkan ambang batas (*threshold*) sebesar 0,95 untuk mengidentifikasi fitur-fitur yang memiliki korelasi sangat tinggi. Apabila terdapat dua fitur dengan nilai korelasi melebihi ambang batas tersebut, salah satu fitur akan dihapus karena dianggap memberikan informasi yang serupa. Proses ini bertujuan untuk mengurangi jumlah fitur yang berlebihan (*multicollinearity*) tanpa menghilangkan informasi penting yang dibutuhkan oleh model klasifikasi.
#
# Hasil dari proses seleksi fitur disimpan pada variabel `x_new`, sedangkan label kelas disimpan pada variabel `y`. Program kemudian menampilkan jumlah fitur sebelum dan sesudah seleksi, serta daftar fitur yang dipertahankan untuk digunakan pada tahap klasifikasi.
#
# Selain itu, dibuat visualisasi berupa *heatmap* korelasi menggunakan library Seaborn untuk menggambarkan hubungan antar fitur yang telah terpilih. Visualisasi ini membantu dalam menganalisis tingkat keterkaitan antar fitur serta memastikan bahwa fitur yang digunakan memiliki korelasi yang lebih rendah sehingga dapat memberikan informasi yang lebih beragam bagi model klasifikasi.

# %%
# Menghitung korelasi antar fitur numerik
feature_data = hasilEkstrak.drop(columns=["Label", "Filename"])
feature_data = feature_data.select_dtypes(include=[np.number])

correlation_matrix = feature_data.corr().abs()

# Menyaring fitur yang memiliki korelasi absolut lebih dari threshold
threshold = 0.95
columns = np.full((correlation_matrix.shape[0],), True, dtype=bool)

for i in range(correlation_matrix.shape[0]):
    for j in range(i + 1, correlation_matrix.shape[0]):
        if correlation_matrix.iloc[i, j] >= threshold:
            if columns[j]:
                columns[j] = False

select = feature_data.columns[columns]
x_new = hasilEkstrak[select]
y = hasilEkstrak["Label"]

print("Jumlah fitur awal:", feature_data.shape[1])
print("Jumlah fitur setelah selection:", len(select))
print("Fitur yang digunakan:")
print(list(select))

plt.figure(figsize=(17, 17))
sns.heatmap(x_new.corr(), annot=True, cmap="Blues", fmt=".2f")
plt.title("Korelasi Fitur Resize + Grayscale + Median")
plt.show()
# Out:
# Jumlah fitur awal: 28
# Jumlah fitur setelah selection: 14
# Fitur yang digunakan:
# ['Contrast0', 'Homogeneity0', 'Dissimilarity0', 'Entropy0', 'ASM0', 'Energy0', 'Correlation0', 'Contrast45', 'Dissimilarity45', 'Correlation45', 'Contrast90', 'Correlation90', 'Contrast135', 'Correlation135']

# %% [markdown]
# ## Splitting Data
#
# Bagian ini digunakan untuk membagi dataset hasil seleksi fitur menjadi data latih (*training data*) dan data uji (*testing data*). Proses pembagian dilakukan menggunakan fungsi `train_test_split()` dari library Scikit-learn. Pada penelitian ini digunakan nilai `test_size = 0.2`, yang berarti 80% data digunakan untuk proses pelatihan model dan 20% data digunakan untuk proses pengujian.
#
# Parameter `random_state = 45` digunakan untuk memastikan bahwa hasil pembagian data tetap konsisten setiap kali program dijalankan. Selain itu, parameter `stratify = y` diterapkan agar proporsi jumlah data pada setiap kelas tetap seimbang antara data latih dan data uji, sehingga distribusi kelas tidak berubah setelah proses pembagian dilakukan.
#
# Hasil pembagian disimpan ke dalam variabel `X_train` dan `y_train` sebagai data latih, serta `X_test` dan `y_test` sebagai data uji. Program kemudian menampilkan ukuran masing-masing dataset serta jumlah data pada setiap kelas untuk memastikan bahwa proses pembagian telah dilakukan dengan benar dan distribusi data tetap terjaga.

# %%
# ubah bagian test_size sesuai kebutuhan
# 0.3 = 30% data untuk testing (train/test 70/30)
# 0.2 = 20% data untuk testing (train/test 80/20)
X_train, X_test, y_train, y_test = train_test_split(
    x_new,
    y,
    test_size=0.2,
    random_state=45,
    stratify=y,
)

print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:")
print(y_train.value_counts())
print("y_test:")
print(y_test.value_counts())
# Out:
# X_train: (112, 14)
# X_test: (28, 14)
# y_train:
# Label
# snail           56
# catterpillar    56
# Name: count, dtype: int64
# y_test:
# Label
# catterpillar    14
# snail           14
# Name: count, dtype: int64

# %% [markdown]
# ## Feature Normalization
#
#
# metode normalisasi menggunakan Standardization (Z-score)
#
#
#
# Bagian ini digunakan untuk melakukan normalisasi fitur menggunakan metode **Z-Score**, yaitu dengan mengurangi setiap nilai fitur dengan nilai rata-ratanya dan membaginya dengan standar deviasi. Normalisasi dilakukan berdasarkan data latih (`X_train`) dan kemudian diterapkan pada data uji (`X_test`) agar tidak terjadi kebocoran data (*data leakage*). Proses ini bertujuan untuk menyamakan skala antar fitur sehingga dapat meningkatkan kinerja model klasifikasi. Setelah normalisasi selesai, data latih ditampilkan untuk memastikan proses berjalan dengan benar.

# %%
# normalisasi mean std
std_train = X_train.std().replace(0, 1)
X_test = (X_test - X_train.mean()) / std_train
X_train = (X_train - X_train.mean()) / std_train

X_train.head()
# Out:
#      Contrast0  Homogeneity0  Dissimilarity0  Entropy0      ASM0   Energy0  \
# 83   -0.624589     -0.102719       -0.601241  0.128171 -0.288624 -0.411752
# 95   -0.524101      0.243129       -0.662221 -0.253656 -0.053332  0.240659
# 45   -0.147398     -0.851359        0.366574  0.744907 -0.319400 -0.541155
# 116  -0.808701      0.449808       -1.104443 -0.530699 -0.224905 -0.193830
# 91   -0.524941      1.423074       -0.834247 -1.550260  0.570127  1.244801
#
#      Correlation0  Contrast45  Dissimilarity45  Correlation45  Contrast90  \
# 83       0.879345   -0.519224        -0.342634       0.947380   -0.359344
# 95       0.851658   -0.652148        -0.738203       1.074812   -0.776707
# 45       0.005025   -0.177982         0.225286      -0.007446    0.131091
# 116      0.925888   -0.877270        -1.035185       1.059002   -0.931465
# 91       0.428232   -0.621878        -0.916546       0.521827   -0.632125
#
#      Correlation90  Contrast135  Correlation135
# ...

# %% [markdown]
# ## Modeling
#
#
#
# ### Define Model
#
#
# Bagian ini digunakan untuk menyiapkan model klasifikasi yang akan digunakan dalam penelitian, yaitu Random Forest, Support Vector Machine (SVM), dan K-Nearest Neighbor (KNN). Model Random Forest dibuat dengan 5 pohon keputusan (n_estimators = 5), SVM menggunakan kernel RBF (Radial Basis Function), sedangkan KNN menggunakan 5 tetangga terdekat (n_neighbors = 5).
#
# Selain itu, dibuat fungsi generateClassificationReport() yang berfungsi menampilkan hasil evaluasi model berupa classification report, confusion matrix, dan nilai akurasi. Variabel hasil_model disiapkan untuk menyimpan hasil evaluasi dari setiap model sehingga dapat digunakan pada tahap perbandingan performa klasifikasi.

# %%
def generateClassificationReport(y_true, y_pred):
    print(classification_report(y_true, y_pred))
    print(confusion_matrix(y_true, y_pred))
    print("Accuracy:", accuracy_score(y_true, y_pred))


rf = RandomForestClassifier(n_estimators=5, random_state=42)
svm = SVC(kernel="rbf", random_state=42)
knn = KNeighborsClassifier(n_neighbors=5)

hasil_model = []

# %% [markdown]
# ### Train Random Forest Classifier
#
#
# Bagian ini digunakan untuk melatih dan menguji model **Random Forest** menggunakan data latih dan data uji yang telah disiapkan sebelumnya. Proses pelatihan dilakukan menggunakan fungsi `fit()` pada data latih (`X_train` dan `y_train`) sehingga model dapat mempelajari pola dari fitur-fitur yang telah diekstraksi.
#
# Setelah proses pelatihan selesai, model digunakan untuk melakukan prediksi pada data latih dan data uji. Hasil prediksi kemudian dievaluasi menggunakan fungsi `generateClassificationReport()` yang menampilkan *classification report*, *confusion matrix*, dan nilai akurasi. Evaluasi pada data latih digunakan untuk melihat kemampuan model dalam mempelajari data, sedangkan evaluasi pada data uji digunakan untuk mengukur kemampuan model dalam mengklasifikasikan data baru yang belum pernah dilihat sebelumnya.
#
# Selanjutnya, nilai performa model yang meliputi **akurasi data latih**, **akurasi data uji**, **precision**, **recall**, dan **F1-score** disimpan ke dalam variabel `hasil_model`. Data ini nantinya digunakan untuk membandingkan performa Random Forest dengan model klasifikasi lainnya.

# %%
# Train Random Forest Classifier
rf.fit(X_train, y_train)

print("------Training Set------")
y_pred_rf_train = rf.predict(X_train)
generateClassificationReport(y_train, y_pred_rf_train)

print("\n------Testing Set------")
y_pred_rf_test = rf.predict(X_test)
generateClassificationReport(y_test, y_pred_rf_test)

hasil_model.append({
    "Percobaan": "resize_grayscale_median",
    "Model": "Random Forest",
    "Train Accuracy": accuracy_score(y_train, y_pred_rf_train),
    "Test Accuracy": accuracy_score(y_test, y_pred_rf_test),
    "Precision": precision_score(y_test, y_pred_rf_test, average="weighted", zero_division=0),
    "Recall": recall_score(y_test, y_pred_rf_test, average="weighted", zero_division=0),
    "F1-Score": f1_score(y_test, y_pred_rf_test, average="weighted", zero_division=0),
})
# Out:
# ------Training Set------
#               precision    recall  f1-score   support
#
# catterpillar       0.95      0.96      0.96        56
#        snail       0.96      0.95      0.95        56
#
#     accuracy                           0.96       112
#    macro avg       0.96      0.96      0.96       112
# weighted avg       0.96      0.96      0.96       112
#
# [[54  2]
#  [ 3 53]]
# Accuracy: 0.9553571428571429
#
# ------Testing Set------
#               precision    recall  f1-score   support
#
# catterpillar       1.00      0.79      0.88        14
#        snail       0.82      1.00      0.90        14
#
#     accuracy                           0.89        28
#    macro avg       0.91      0.89      0.89        28
# weighted avg       0.91      0.89      0.89        28
#
# [[11  3]
#  [ 0 14]]
# Accuracy: 0.8928571428571429

# %% [markdown]
# ### Train SVM Classifier
#
# Bagian ini digunakan untuk melatih dan menguji model Support Vector Machine (SVM) menggunakan data yang telah melalui proses preprocessing, ekstraksi fitur, dan normalisasi. Proses pelatihan dilakukan dengan fungsi fit() pada data latih (X_train dan y_train) sehingga model dapat mempelajari pola dari fitur yang tersedia.
#
# Setelah model selesai dilatih, dilakukan prediksi pada data latih dan data uji untuk melihat performa model dalam mengenali data yang sudah dipelajari maupun data baru. Hasil prediksi kemudian dievaluasi menggunakan fungsi generateClassificationReport() yang menampilkan classification report, confusion matrix, serta nilai akurasi untuk masing-masing set data.
#
# Selanjutnya, nilai performa model seperti akurasi data latih, akurasi data uji, precision, recall, dan F1-score disimpan ke dalam variabel hasil_model. Data ini nantinya digunakan untuk membandingkan kinerja SVM dengan model klasifikasi lainnya.

# %%
# Train SVM Classifier
svm.fit(X_train, y_train)

print("------Training Set------")
y_pred_svm_train = svm.predict(X_train)
generateClassificationReport(y_train, y_pred_svm_train)

print("\n------Testing Set------")
y_pred_svm_test = svm.predict(X_test)
generateClassificationReport(y_test, y_pred_svm_test)

hasil_model.append({
    "Percobaan": "resize_grayscale_median",
    "Model": "SVM",
    "Train Accuracy": accuracy_score(y_train, y_pred_svm_train),
    "Test Accuracy": accuracy_score(y_test, y_pred_svm_test),
    "Precision": precision_score(y_test, y_pred_svm_test, average="weighted", zero_division=0),
    "Recall": recall_score(y_test, y_pred_svm_test, average="weighted", zero_division=0),
    "F1-Score": f1_score(y_test, y_pred_svm_test, average="weighted", zero_division=0),
})
# Out:
# ------Training Set------
#               precision    recall  f1-score   support
#
# catterpillar       0.93      0.77      0.84        56
#        snail       0.80      0.95      0.87        56
#
#     accuracy                           0.86       112
#    macro avg       0.87      0.86      0.86       112
# weighted avg       0.87      0.86      0.86       112
#
# [[43 13]
#  [ 3 53]]
# Accuracy: 0.8571428571428571
#
# ------Testing Set------
#               precision    recall  f1-score   support
#
# catterpillar       1.00      0.79      0.88        14
#        snail       0.82      1.00      0.90        14
#
#     accuracy                           0.89        28
#    macro avg       0.91      0.89      0.89        28
# weighted avg       0.91      0.89      0.89        28
#
# [[11  3]
#  [ 0 14]]
# Accuracy: 0.8928571428571429

# %% [markdown]
# ### Train KNN Classifier
#
# Bagian ini digunakan untuk melatih dan menguji model K-Nearest Neighbor (KNN) menggunakan data latih yang telah diproses sebelumnya. Model dilatih dengan data X_train dan y_train, kemudian digunakan untuk melakukan prediksi pada data latih maupun data uji. Hasil prediksi dievaluasi menggunakan classification report, confusion matrix, serta nilai akurasi untuk melihat performa model dalam proses klasifikasi. Selanjutnya, nilai evaluasi seperti accuracy, precision, recall, dan F1-score disimpan ke dalam hasil_model. Setelah semua model selesai dievaluasi, seluruh hasil dirangkum ke dalam DataFrame untuk memudahkan perbandingan performa antar model klasifikasi yang digunakan.

# %%
# Train KNN Classifier
knn.fit(X_train, y_train)

print("------Training Set------")
y_pred_knn_train = knn.predict(X_train)
generateClassificationReport(y_train, y_pred_knn_train)

print("\n------Testing Set------")
y_pred_knn_test = knn.predict(X_test)
generateClassificationReport(y_test, y_pred_knn_test)

hasil_model.append({
    "Percobaan": "resize_grayscale_median",
    "Model": "KNN",
    "Train Accuracy": accuracy_score(y_train, y_pred_knn_train),
    "Test Accuracy": accuracy_score(y_test, y_pred_knn_test),
    "Precision": precision_score(y_test, y_pred_knn_test, average="weighted", zero_division=0),
    "Recall": recall_score(y_test, y_pred_knn_test, average="weighted", zero_division=0),
    "F1-Score": f1_score(y_test, y_pred_knn_test, average="weighted", zero_division=0),
})

df_hasil_model = pd.DataFrame(hasil_model)
print("Ringkasan hasil klasifikasi:")
df_hasil_model
# Out:
# ------Training Set------
#               precision    recall  f1-score   support
#
# catterpillar       0.94      0.79      0.85        56
#        snail       0.82      0.95      0.88        56
#
#     accuracy                           0.87       112
#    macro avg       0.88      0.87      0.87       112
# weighted avg       0.88      0.87      0.87       112
#
# [[44 12]
#  [ 3 53]]
# Accuracy: 0.8660714285714286
#
# ------Testing Set------
#               precision    recall  f1-score   support
#
# catterpillar       0.93      0.93      0.93        14
#        snail       0.93      0.93      0.93        14
#
#     accuracy                           0.93        28
#    macro avg       0.93      0.93      0.93        28
# weighted avg       0.93      0.93      0.93        28
#
# [[13  1]
#  [ 1 13]]
# Accuracy: 0.9285714285714286
# Ringkasan hasil klasifikasi:
#                  Percobaan          Model  Train Accuracy  Test Accuracy  \
# ...

# %% [markdown]
# ## Evaluation With Confusion Matrix
#
#
# Bagian ini digunakan untuk menampilkan hasil evaluasi model dalam bentuk confusion matrix. Fungsi plot_confusion_matrix() menerima nilai data aktual (y_true) dan hasil prediksi (y_pred), kemudian menghitung confusion matrix menggunakan confusion_matrix() dari Scikit-learn. Hasil tersebut kemudian divisualisasikan menggunakan ConfusionMatrixDisplay dengan warna biru (Blues colormap) agar lebih mudah dibaca.
#
# Visualisasi ini dilakukan untuk ketiga model yang digunakan, yaitu Random Forest, SVM, dan KNN, sehingga dapat dibandingkan secara langsung performa masing-masing model dalam mengklasifikasikan data uji.

# %%
def plot_confusion_matrix(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap=plt.cm.Blues)
    plt.title(title)
    plt.show()


plot_confusion_matrix(y_test, y_pred_rf_test, "Random Forest Confusion Matrix")
plot_confusion_matrix(y_test, y_pred_svm_test, "SVM Confusion Matrix")
plot_confusion_matrix(y_test, y_pred_knn_test, "KNN Confusion Matrix")
